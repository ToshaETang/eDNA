# %%
'''
# SUBRIVER LIST (13)
CuKeng
NanShi
SongLuo
FanFan
SanGuang
BaoYan
FuBuEr
MeiYou
QingShui
TianGou
TuChang
MeiLuo
TaiGang
'''
# Out:
# '\n# SUBRIVER LIST (13)\nCuKeng\nNanShi\nSongLuo\nFanFan\nSanGuang\nBaoYan\nFuBuEr\nMeiYou\nQingShui\nTianGou\nTuChang\nMeiLuo\nTaiGang\n'

# %%
import pandas as pd

# %%
# READ RAWDATA   df_all = pd.read_csv(r'YOUR DATA PATH')

df_all = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\工作\eDNA\sub_river_creatures\1106\river_creature_22.csv')
df_all = pd.DataFrame(df_all)

# %%
df_all
# Out:
#          OID_         id                 observed_o       observed_1  \
# 0          10     531649                  2010/7/31  2010/7/31 00:00
# 1          11     531690                  2010/7/31  2010/7/31 00:00
# 2          13     826862                  2014/8/11  2014/8/11 00:00
# 3          14     826871                  2014/8/11  2014/8/11 00:00
# 4          17    1073629                   5-May-14   2014/5/5 00:00
# ...       ...        ...                        ...              ...
# 46047  152506  189938228  2023-11-04 09:41:48+08:00  2023/11/4 00:00
# 46048  152507  189938262  2023-11-04 09:28:59+08:00  2023/11/4 00:00
# 46049  152509  189941780            2023/11/4 12:00  2023/11/4 00:00
# 46050  152510  189941804            2023/11/4 15:24  2023/11/4 00:00
# 46051  152511  189941813            2023/11/4 15:25  2023/11/4 00:00
#
#                     time_obser                   time_zone  user_id  \
# 0                                                   Taipei    30498
# 1                                                   Taipei    30498
# 2                                                Hong Kong    45036
# 3                                                Hong Kong    45036
# 4                               Pacific Time (US & Canada)     8060
# ...                        ...                         ...      ...
# 46047  2023-11-04 01:41:48 UTC                      Taipei  1651824
# 46048  2023-11-04 01:28:59 UTC                      Taipei  1651824
# 46049  2023-11-04 04:00:09 UTC                      Taipei  7488415
# 46050  2023-11-04 07:24:41 UTC                      Taipei  7488415
# 46051  2023-11-04 07:25:51 UTC                      Taipei  7488415
#
#          user_login    user_name               created_at  ... taxon_su_3  \
# 0      yaofong_tsao               2014-02-15 14:13:07 UTC  ...
# 1      yaofong_tsao               2014-02-15 16:08:05 UTC  ...
# 2        glendaheng  Glenda Heng  2014-08-11 16:59:25 UTC  ...
# 3        glendaheng  Glenda Heng  2014-08-11 17:07:16 UTC  ...
# 4           herpguy   Paul Freed  2014-11-14 20:55:51 UTC  ...
# ...             ...          ...                      ...  ...        ...
# 46047   orange_papa     橘子拔(橘子熊)  2023-11-04 10:18:21 UTC  ...
# 46048   orange_papa     橘子拔(橘子熊)  2023-11-04 10:19:19 UTC  ...
# 46049   gloria89199  Gloria Chen  2023-11-04 11:25:49 UTC  ...
# 46050   gloria89199  Gloria Chen  2023-11-04 11:25:56 UTC  ...
# 46051   gloria89199  Gloria Chen  2023-11-04 11:26:04 UTC  ...
#
#           taxon_trib    taxon_subt   taxon_genu taxon_ge_1  \
# 0                                      Odorrana
# 1                                   Limnonectes
# 2          Agathiini                    Agathia
# 3         Lithosiini     Nudariina        Cyana
# 4                                       Lycodon
# ...              ...           ...          ...        ...
# 46047       Arctiini   Spilosomina   Spilarctia
# 46048       Cardueae  Saussureinae      Jurinea
# 46049
# 46050  Dissochaeteae                  Medinilla
# 46051    Colocasieae                   Alocasia
#
#                     taxon_spec taxon_hybr taxon_subs  taxon_form     river
# 0           Odorrana swinhoana                                      NanShi
# 1      Limnonectes fujianensis                                      NanShi
# 2              Agathia laetata                                      NanShi
# 3          Cyana quadripartita                                      NanShi
# 4            Lycodon ruhstrati                                    SanGuang
# ...                        ...        ...        ...         ...       ...
# 46047     Spilarctia subcarnea                                    SanGuang
# 46048        Jurinea deltoidea                                    SanGuang
# 46049                                                               NanShi
# 46050                                                               NanShi
# 46051           Alocasia odora                                      NanShi
#
# [46052 rows x 62 columns]

# %%
# SEPERATE RIVERS   df_XXX = df_all[df_all['river'] == "XXX"].reset_index(drop=True)

df_CuKeng = df_all[df_all['river'] == "CuKeng"].reset_index(drop=True)
df_NanShi = df_all[df_all['river'] == "NanShi"].reset_index(drop=True)
df_SongLuo = df_all[df_all['river'] == "SongLuo"].reset_index(drop=True)
df_FanFan = df_all[df_all['river'] == "FanFan"].reset_index(drop=True)
df_SanGuang = df_all[df_all['river'] == "SanGuang"].reset_index(drop=True)
df_BaoYan = df_all[df_all['river'] == "BaoYan"].reset_index(drop=True)
df_FuBuEr = df_all[df_all['river'] == "FuBuEr"].reset_index(drop=True)
df_MeiYou = df_all[df_all['river'] == "MeiYou"].reset_index(drop=True)
df_QingShui = df_all[df_all['river'] == "QingShui"].reset_index(drop=True)
df_TianGou = df_all[df_all['river'] == "TianGou"].reset_index(drop=True)
df_TuChang = df_all[df_all['river'] == "TuChang"].reset_index(drop=True)
df_MeiLuo = df_all[df_all['river'] == "MeiLuo"].reset_index(drop=True)
df_TaiGang = df_all[df_all['river'] == "TaiGang"].reset_index(drop=True)

print(len(df_CuKeng))
print(len(df_NanShi))
print(len(df_SongLuo))
print(len(df_FanFan))
print(len(df_SanGuang))
print(len(df_BaoYan))
print(len(df_FuBuEr))
print(len(df_MeiYou))
print(len(df_QingShui))
print(len(df_TianGou))
print(len(df_TuChang))
print(len(df_MeiLuo))
print(len(df_TaiGang))
# Out:
# 9626
# 14641
# 2786
# 4351
# 5068
# 30
# 606
# 322
# 985
# 1825
# 1728
# 7
# 4077

# %%
df_NanShi
# Out:
#          OID_         id                 observed_o        observed_1  \
# 0          10     531649                  2010/7/31   2010/7/31 00:00
# 1          11     531690                  2010/7/31   2010/7/31 00:00
# 2          13     826862                  2014/8/11   2014/8/11 00:00
# 3          14     826871                  2014/8/11   2014/8/11 00:00
# 4          22    2361982                 2012/10/11  2012/10/11 00:00
# ...       ...        ...                        ...               ...
# 14636  152451  189926214  2023-07-17 08:44:33+08:00   2023/7/17 00:00
# 14637  152452  189926282  2023-07-17 08:47:43+08:00   2023/7/17 00:00
# 14638  152509  189941780            2023/11/4 12:00   2023/11/4 00:00
# 14639  152510  189941804            2023/11/4 15:24   2023/11/4 00:00
# 14640  152511  189941813            2023/11/4 15:25   2023/11/4 00:00
#
#                     time_obser        time_zone  user_id    user_login  \
# 0                                        Taipei    30498  yaofong_tsao
# 1                                        Taipei    30498  yaofong_tsao
# 2                                     Hong Kong    45036    glendaheng
# 3                                     Hong Kong    45036    glendaheng
# 4                               Central America   125469    airrocksun
# ...                        ...              ...      ...           ...
# 14636  2023-07-17 00:44:33 UTC           Taipei  2335620          ijou
# 14637  2023-07-17 00:47:43 UTC           Taipei  2335620          ijou
# 14638  2023-11-04 04:00:09 UTC           Taipei  7488415   gloria89199
# 14639  2023-11-04 07:24:41 UTC           Taipei  7488415   gloria89199
# 14640  2023-11-04 07:25:51 UTC           Taipei  7488415   gloria89199
#
#          user_name               created_at  ... taxon_su_3     taxon_trib  \
# 0                   2014-02-15 14:13:07 UTC  ...
# 1                   2014-02-15 16:08:05 UTC  ...
# 2      Glenda Heng  2014-08-11 16:59:25 UTC  ...                 Agathiini
# 3      Glenda Heng  2014-08-11 17:07:16 UTC  ...                Lithosiini
# 4                   2015-11-08 22:52:19 UTC  ...
# ...            ...                      ...  ...        ...            ...
# 14636          蕭逸柔  2023-11-04 05:37:37 UTC  ...
# 14637          蕭逸柔  2023-11-04 05:38:54 UTC  ...                  Sicyoeae
# 14638  Gloria Chen  2023-11-04 11:25:49 UTC  ...
# 14639  Gloria Chen  2023-11-04 11:25:56 UTC  ...             Dissochaeteae
# 14640  Gloria Chen  2023-11-04 11:26:04 UTC  ...               Colocasieae
#
#       taxon_subt     taxon_genu taxon_ge_1               taxon_spec  \
# 0                      Odorrana                  Odorrana swinhoana
# 1                   Limnonectes             Limnonectes fujianensis
# 2                       Agathia                     Agathia laetata
# 3      Nudariina          Cyana                 Cyana quadripartita
# 4                     Myophonus                 Myophonus insularis
# ...          ...            ...        ...                      ...
# 14636                 Diplazium                  Diplazium donianum
# 14637             Trichosanthes
# 14638
# 14639                 Medinilla
# 14640                  Alocasia                      Alocasia odora
#
#       taxon_hybr taxon_subs  taxon_form   river
# 0                                        NanShi
# 1                                        NanShi
# 2                                        NanShi
# 3                                        NanShi
# 4                                        NanShi
# ...          ...        ...         ...     ...
# 14636                                    NanShi
# 14637                                    NanShi
# 14638                                    NanShi
# 14639                                    NanShi
# 14640                                    NanShi
#
# [14641 rows x 62 columns]

# %%
# FIND SPECIES   species_XXX = df_XXX['scientific'].drop_duplicates().reset_index(drop=True).tolist()

species_all = df_all['scientific'].drop_duplicates().reset_index(drop=True).tolist()

species_CuKeng = df_CuKeng['scientific'].drop_duplicates().reset_index(drop=True).tolist()
species_NanShi = df_NanShi['scientific'].drop_duplicates().reset_index(drop=True).tolist()
species_SongLuo = df_SongLuo['scientific'].drop_duplicates().reset_index(drop=True).tolist()
species_FanFan = df_FanFan['scientific'].drop_duplicates().reset_index(drop=True).tolist()
species_SanGuang = df_SanGuang['scientific'].drop_duplicates().reset_index(drop=True).tolist()
species_BaoYan = df_BaoYan['scientific'].drop_duplicates().reset_index(drop=True).tolist()
species_FuBuEr = df_FuBuEr['scientific'].drop_duplicates().reset_index(drop=True).tolist()
species_MeiYou = df_MeiYou['scientific'].drop_duplicates().reset_index(drop=True).tolist()
species_QingShui = df_QingShui['scientific'].drop_duplicates().reset_index(drop=True).tolist()
species_TianGou = df_TianGou['scientific'].drop_duplicates().reset_index(drop=True).tolist()
species_TuChang = df_TuChang['scientific'].drop_duplicates().reset_index(drop=True).tolist()
species_MeiLuo = df_MeiLuo['scientific'].drop_duplicates().reset_index(drop=True).tolist()
species_TaiGang = df_TaiGang['scientific'].drop_duplicates().reset_index(drop=True).tolist()

# %%
species_all
# Out:
# ['Odorrana swinhoana',
#  'Limnonectes fujianensis',
#  'Agathia laetata',
#  'Cyana quadripartita',
#  'Lycodon ruhstrati',
#  'Pareas atayal',
#  'Myophonus insularis',
#  'Urocissa caerulea',
#  'Actinodura morrisoniana',
#  'Delichon dasypus',
#  'Trochalopteron morrisonianum',
#  'Hypsipetes leucocephalus',
#  'Liocichla steerii',
#  'Niltava vivida',
#  'Yuhina brunneiceps',
#  'Diploderma polygonatum xanthostomum',
#  'Erasmia pulchella hobsoni',
#  'Fejervarya limnocharis',
#  'Hylarana latouchii',
#  'Buergeria choui',
#  'Lissachatina immaculata',
#  'Zhangixalus taipeianus',
#  'Polyura narcaea meghaduta',
#  'Harmonia dimidiata',
#  'Itea oldhamii',
#  'Peperomia japonica',
#  'Litsea cubeba',
#  'Arenga engleri',
#  'Desmodiinae',
#  'Sambucus javanica',
#  'Asarum taipingshanianum',
#  'Sphagnum',
#  'Polypodiodes formosana',
#  'Teleopsis quadriguttata',
#  'Asiophrida spectabilis',
#  'Sedum actinocarpum',
#  'Drynaria coronans',
#  'Appias lyncida',
#  'Fungi',
#  'Dryopteris varia',
#  'Lycianthes biflora',
#  'Asplenium cuneatiforme',
#  'Titanotrichum oldhamii',
#  'Hydrangea involucrata longifolia',
#  'Juglans mandshurica mandshurica',
#  'Petasites formosanus',
#  'Rhododendron formosanum',
#  'Ranunculus cantoniensis',
#  'Heterotropa',
#  'Pilea matsudae',
#  'Paris polyphylla stenophylla',
#  'Sanicula petagnioides',
#  'Disporum sessile intermedium',
#  'Ainsliaea henryi',
#  'Arisaema taiwanense',
#  'Dryopteris peranema',
#  'Viola formosana',
#  'Arachniodes amabilis fimbriata',
#  'Persicaria biconvexa',
#  'Microporus affinis',
#  'Dryopteris formosana',
#  'Hemielimaea formosana',
#  'Motacilla alba',
#  'Bipaliinae',
#  'Melanitis',
#  'Neofelis nebulosa',
#  'Horisme macularia',
#  'Sphenomorphus indicus',
#  'Microhyla fissipes',
#  'Phelotrupes formosanus',
#  'Opiliones',
#  'Coptis morii',
#  'Magnoliopsida',
#  'Monotropastrum humile',
#  'Cheiropleuria integrifolia',
#  'Cercidiphyllum japonicum',
#  'Calanthe aristulifera',
#  'Calanthe striata',
#  'Ardisia japonica',
#  'Eriobotrya deflexa',
#  'Maesa perlaria formosana',
#  'Strobilanthes rankanensis',
#  'Nubelaria arisanensis',
#  'Persicaria',
#  'Nanocnide japonica',
#  'Ajuga taiwanensis',
#  'Clematis uncinata',
#  'Viola nagasawae',
#  'Deutzia taiwanensis',
#  'Corydalis pallida',
#  'Cardamine impatiens',
#  'Urtica thunbergiana',
#  'Trifolium repens',
#  'Oenanthe javanica',
#  'Excoecaria cochinchinensis',
#  'Rhododendron',
#  'Prunus persica',
#  'Heptapleurum arboricola',
#  'Citrus maxima',
#  'Eutacta',
#  'Trema orientale',
#  'Piper kadsura',
#  'Nephrolepis cordifolia',
#  'Bidens alba',
#  'Persicaria chinensis',
#  'Ficus microcarpa',
#  'Juniperus chinensis',
#  'Calocedrus formosana',
#  'Prunus mume',
#  'Crassocephalum crepidioides',
#  'Mazus pumilus',
#  'Plantago major',
#  'Clinopodium gracile',
#  'Polypogon fugax',
#  'Potentilla',
#  'Theaceae',
#  'Platycladus orientalis',
#  'Tracheophyta',
#  'Callicarpa formosana',
#  'Deutzia pulchra',
#  'Osmanthus fragrans',
#  'Phalaenopsis',
#  'Cyclophorus formosaensis',
#  'Plectotropis mackensii',
#  'Myotis rufoniger',
#  'Metaphire',
#  'Mammalia',
#  'Sus scrofa taivanus',
#  'Monachosorum henryi',
#  'Actias sinensis subaurea',
#  'Notodontidae',
#  'Halmus chalybeus',
#  'Centrochelys sulcata',
#  'Matrona cyanoptera',
#  'Prunus campanulata',
#  'Trimeresurus stejnegeri',
#  'Lycodon rufozonatus',
#  'Protobothrops mucrosquamatus',
#  'Fissistigma glaucescens',
#  'Epidaus sexspinus',
#  'Neopanorpa',
#  'Dichorragia nesimachus',
#  'Xystodesmidae',
#  'Calosoma maximowiczi',
#  'Nymphalis xanthomelas',
#  'Nidirana adenopleura',
#  'Tessaratoma papillosa',
#  'Graphium doson',
#  'Dryopteris',
#  'Lemmaphyllum microphyllum',
#  'Dysosma pleiantha',
#  'Eupatorium chinense tozanense',
#  'Acanthophippium striatum',
#  'Ophioderma pendulum',
#  'Impatiens tayemonii',
#  'Psolodesmus mandarinus dorothea',
#  'Orthetrum triangulare',
#  'Ciconia boyciana',
#  'Melastoma candidum',
#  'Houttuynia cordata',
#  'Solanum pseudocapsicum',
#  'Malvaviscus arboreus',
#  'Bayadera brevicauda',
#  'Orthetrum melania',
#  'Muntiacus reevesi',
#  'Nephila pilipes',
#  'Canna indica',
#  'Coptocephala pallens',
#  'Hoplobatrachus chinensis',
#  'Polistes rothneyi',
#  'Kurixalus idiootocus',
#  'Pseudocopera ciliata',
#  'Corymica pryeri',
#  'Sipyloidea sipylus',
#  'Heteropoda venatoria',
#  'Argiope aetheroides',
#  ' ',
#  'Taenioptynx brodiei',
#  'Dendrocopos leucotos',
#  'Araneae',
#  'Polyporales',
#  'Therates fruhstorferi sauteri',
#  'Buergeria otai',
#  'Trigoniulus tertius',
#  'Bufo bankorensis',
#  'Eterusia',
#  'Titanodula formosana',
#  'Calletaera obliquata',
#  'Urva urva formosana',
#  'Rana sauteri',
#  'Euthalia formosana',
#  'Kaniska canace',
#  'Tsutsusi',
#  'Anoplophora wusheana',
#  'Cantao ocellatus',
#  'Asota plana lacteata',
#  'Graphium doson postianus',
#  'Chrysochroa fulgidissima',
#  'Columba livia domestica',
#  'Cheirotonus formosanus',
#  'Melaleuca',
#  'Macaca cyclopis',
#  'Sephisa daimio',
#  'Erigeron annuus',
#  'Sarcopyramis napalensis delicata',
#  'Indolestes cyaneus',
#  'Agaricales',
#  'Anura',
#  'Orientus',
#  'Diploderma brevipes',
#  'Murina puta',
#  'Murininae',
#  'Xenocatantops brachycerus',
#  'Crocosmia × crocosmiiflora',
#  'Medinilla fengii',
#  'Euonymus laxiflorus',
#  'Lycoperdon',
#  'Epilachnini',
#  'Onychargia atrocyana',
#  'Vespa velutina',
#  'Nymphalidae',
#  'Asota plana',
#  'Hyla chinensis',
#  'Ficus erecta beecheyana',
#  'Lycoperdaceae',
#  'Amanita',
#  'Polytrichaceae',
#  'Valeriana hsui',
#  'Boletales',
#  'Tettigoniidae',
#  'Pomponia',
#  'Diploderma swinhonis',
#  'Ceriagrion fallax',
#  'Debregeasia orientalis',
#  'Ceriagrion auranticum',
#  'Paracercion calamorum',
#  'Artona hainana',
#  'Agriocnemis femina oryzae',
#  'Xenocatantops humile',
#  'Lobelia chinensis',
#  'Glenea lineata sauteri',
#  'Languriini',
#  'Life',
#  'Momordica charantia',
#  'Salvia formosana matsudae',
#  'Prosopocoilus forficula',
#  'Rhaetulus crenatus',
#  'Prosopocoilus astacoides blanchardi',
#  'Kurixalus eiffingeri',
#  'Mycalesina',
#  'Calanthe masuca',
#  'Ophiopogon intermedius',
#  'Agaricus',
#  'Telchinia issoria',
#  'Pterygota',
#  'Trypoxylus dichotomus tsunobosonis',
#  'Ptyas dhumnades',
#  'Zhangixalus prasinatus',
#  'Polistes gigas',
#  'Ptyas major',
#  'Liriope muscari',
#  'Serrognathus titanus sika',
#  'Pseudorhaetus sinicus concolor',
#  'Neolucanus swinhoei',
#  'Satsuma polymorpha',
#  'Eugryllacris cylindrigera',
#  'Mecopoda elongata',
#  'Bungarus multicinctus',
#  'Pseudorhynchus gigas',
#  'Calanthe triplicata',
#  'Cicadidae',
#  'Chitoria chrysolora',
#  'Amata perixanthia',
#  'Lophura swinhoii',
#  'Aix galericulata',
#  'Miltochrista sauteri',
#  'Plantae',
#  'Marumba dyras',
#  'Polygonatum arisanense',
#  'Ellisiophyllum pinnatum',
#  'Trigonotis formosana',
#  'Veronica persica',
#  'Pueraria montana lobata',
#  'Oenanthe javanica rosthornii',
#  'Paederia foetida',
#  'Lagerstroemia subcostata',
#  'Nyctemera adversata',
#  'Fraxinus griffithii',
#  'Pothos chinensis',
#  'Prunella vulgaris',
#  'Ageratum houstonianum',
#  'Argiope',
#  'Spilornis cheela',
#  'Polypedates braueri',
#  'Takydromus viridipunctatus',
#  'Draconinae',
#  'Theopompa ophthalmica',
#  'Oligodon formosanus',
#  'Vespa ducalis',
#  'Lyriothemis elegantissima',
#  'Pomacea canaliculata',
#  'Gastropoda',
#  'Lepidoptera',
#  'Trapa',
#  'Deronectina',
#  'Caelifera',
#  'Aix sponsa',
#  'Anas platyrhynchos',
#  'Cygnus atratus',
#  'Cryptalaus larvatus',
#  'Tragelaphus eurycerus',
#  'Scarabaeidae',
#  'Lymantria monacha',
#  'Dichorragia nesimachus formosanus',
#  'Cyphochilus',
#  'Celastrina lavendularis',
#  'Choaspes benjaminii',
#  'Amorphophallus kiusianus',
#  'Acridotheres cristatellus',
#  'Potamiscinae',
#  'Ascalaphinae',
#  'Cyrtarachne',
#  'Trachyzulpha formosana',
#  'Sphenomorphus',
#  'Arachniodes',
#  'Scincidae',
#  'Rubus rosifolius',
#  'Cryptotympana holsti',
#  'Cinnamomum austrosinense',
#  'Hydrangea chinensis',
#  'Erionota torus',
#  'Hexacentrus unicolor',
#  'Candidiopotamon rathbuni',
#  'Nesiohelix swinhoei',
#  'Crocothemis servilia servilia',
#  'Attacus atlas formosanus',
#  'Riukiaria cohaesiva',
#  'Callidula attenuata',
#  'Buergeria robusta',
#  'Saurauia tristyla oldhamii',
#  'Begonia formosana',
#  'Mitrastemon yamamotoi',
#  'Trametes versicolor',
#  'Pnoepyga formosana',
#  'Jungermanniales',
#  'Dicranaceae',
#  'Myriactis humilis',
#  'Rubus croceacanthus croceacanthus',
#  'Clavaria',
#  'Neanotis hirsuta',
#  'Carex cruciata',
#  'Sephisa chandra',
#  'Alocasia odora',
#  'Colocasia esculenta',
#  'Musa',
#  'Solanum capsicoides',
#  'Mecopoda niponensis',
#  'Ardisia virens',
#  'Pseudocyclosorus esquirolii',
#  'Tubocapsicum anomalum',
#  'Amischotolype glabrata',
#  'Boehmeria formosana',
#  'Ageratum conyzoides',
#  'Pteris wallichiana',
#  'Elatostema platyphyllum',
#  'Rorippa indica',
#  'Yinshania rivulorum',
#  'Scutellaria indica',
#  'Ixeridium laevigatum',
#  'Boehmeria nivea tenacissima',
#  'Lysionotus pauciflorus',
#  'Pilea rotundinucula',
#  'Dichrocephala integrifolia',
#  'Lucanus swinhoei',
#  'Papilio polytes',
#  'Neope muirheadii nagasawae',
#  'Shortia rotundifolia',
#  'Leucauge',
#  'Oxya',
#  'Actinidia setosa',
#  'Hersiliidae',
#  'Abraximorpha davidii',
#  'Rhene atrata',
#  'Dicliptera japonica',
#  'Cuphea carthagenensis',
#  'Salvia',
#  'Mazus miquelii',
#  'Tricyrtis formosana glandosa',
#  'Eriocapitella vitifolia',
#  'Meghimatium',
#  'Pieris canidia',
#  'Ampittia virgata myakei',
#  'Traulia ornata',
#  'Tagiades cohaerens',
#  'Timelaea albescens',
#  'Cyrtophora moluccensis',
#  'Sinopodisma shirakii',
#  'Kallima inachus formosana',
#  'Lithosiini',
#  'Epicauta hirticornis',
#  'Laevicaulis alte',
#  'Psacothea hilaris',
#  'Opisthoplatia orientalis',
#  'Ceresium',
#  'Adoretus',
#  'Ducetia japonica',
#  'Cyana hamata hamata',
#  'Rhabdoblatta karnyi',
#  'Animalia',
#  'Parum colligata',
#  'Erebus ephesperis',
#  'Cetoniinae',
#  'Cylindera kaleea',
#  'Setaria palmifolia',
#  'Selaginella',
#  'Paraphlomis javanica',
#  'Nekemias cantoniensis',
#  'Diplazium dilatatum',
#  'Ctenitis eatonii',
#  'Urticaceae',
#  'Angiospermae',
#  'Alpinia zerumbet',
#  'Diplazium viridissimum',
#  'Tetragnathidae',
#  'Rubus',
#  'Coccinelloidea',
#  'Ericaceae',
#  'Syzygium formosanum',
#  'Neoscona',
#  'Anabropsini',
#  'Physopelta quadriguttata',
#  'Zhangixalus moltrechti',
#  'Narosoideus flavidorsalis',
#  'Plestiodon elegans',
#  'Cichorieae',
#  'Apis cerana',
#  'Anax',
#  'Trapa natans',
#  'Parapodisma',
#  'Polyommatini',
#  'Eurema blanda',
#  'Brachydiplax chalybea flavovittata',
#  'Alcippe morrisonia',
#  'Sabia swinhoei',
#  'Crematogaster',
#  'Parantica aglea maghaba',
#  'Ictinogomphus rapax',
#  'Lygodium japonicum',
#  'Aves',
#  'Alsophila spinulosa',
#  'Orthetrum pruinosum neglectum',
#  'Athyma selenophora',
#  'Macroglossinae',
#  'Ypthima',
#  'Hypolimnas bolina kezia',
#  'Cyperaceae',
#  'Mallotus japonicus',
#  'Argynnis hyperbius',
#  'Polistes',
#  'Liriope',
#  'Ardisia violacea',
#  'Vespa basalis',
#  'Ceriagrion auranticum ryukyuanum',
#  'Ludwigia octovalvis',
#  'Drymaria cordata',
#  'Cyperus exaltatus',
#  'Cosmodela batesi',
#  'Equisetum ramosissimum',
#  'Hoya carnosa',
#  'Reynoutria multiflora',
#  'Pseudognaphalium affine',
#  'Rubus fraxinifolius',
#  'Dysphania ambrosioides',
#  'Athyma cama zoroastres',
#  'Hydrocotyle nepalensis',
#  'Thelypteridoideae',
#  'Kanoscarta kanoniella',
#  'Euphaea formosa',
#  'Calyptratae',
#  'Anas crecca',
#  'Amaurornis phoenicurus',
#  'Calanthe puberula',
#  'Illicium arborescens',
#  'Elaeocarpus japonicus',
#  'Sarcandra glabra',
#  'Persicaria pubescens',
#  'Ideopsis similis',
#  'Pantala flavescens',
#  'Orthetrum sabina',
#  'Salticidae',
#  'Jamides alecto dromicus',
#  'Ricania sublimata',
#  'Tipulidae',
#  'Syrphidae',
#  'Cletus punctiger',
#  'Tetriginae',
#  'Pistia stratiotes',
#  'Hedychium coronarium',
#  'Ceratopteris thalictroides',
#  'Brachydiplax chalybea',
#  'Ischnura senegalensis',
#  'Acisoma panorpoides',
#  'Scleroderma citrinum',
#  'Entoloma murrayi',
#  'Laccaria laccata',
#  'Dianthus palinensis',
#  'Asarum ampulliflorum',
#  'Jasminum lanceolarium',
#  'Syntomoides imaon',
#  'Machilus zuihoensis',
#  'Vagitanus terminalis',
#  'Psolodesmus mandarinus mandarinus',
#  'Acer palmatum',
#  'Brassica oleracea acephala',
#  'Coleoptera',
#  'Graphium sarpedon',
#  'Popillia',
#  'Jamides alecto',
#  'Rhinolophus monoceros',
#  'Opogona nipponica',
#  'Syntomini',
#  'Bradybaena similaris',
#  'Takydromus',
#  'Lissachatina fulica',
#  'Gymnastes shirakii',
#  'Hasarius adansoni',
#  'Euterpnosia',
#  'Actias ningpoana',
#  'Loepa formosensis',
#  'Mesastrape fulguraria',
#  'Amblychia angeronaria',
#  'Orthetrum glaucum',
#  'Rhipidolestes aculeatus',
#  'Tachybaptus ruficollis',
#  'Dicrurus aeneus',
#  'Pycnonotus sinensis',
#  'Dendrobium chameleon',
#  'Commelina diffusa',
#  'Diplopterygium glaucum',
#  'Plagiogyria glauca',
#  'Daphniphyllum macropodum',
#  'Quercus morii',
#  'Rhododendron latoucheae',
#  'Morus indica',
#  'Myrmarachnina',
#  'Leucauge celebesiana',
#  'Penthema formosanum',
#  'Cupha erymanthis',
#  'Ypthima baldus zodina',
#  'Daimio tethys moori',
#  'Discophora sondaica',
#  'Seseria formosana',
#  'Celastrina lavendularis himilcon',
#  'Eurema andersoni',
#  'Prosotas nora formosana',
#  'Rapala varuna formosana',
#  'Tongeia hainani',
#  'Lethe europa',
#  'Papilio memnon',
#  'Junonia iphita',
#  'Caltoris cahira austeni',
#  'Notocrypta curvifascia',
#  'Celaenorrhinus maculosa',
#  'Ichneumonidae',
#  'Rostratula benghalensis',
#  'Poaceae',
#  'Selaginella involvens',
#  'Insecta',
#  'Melanitis phedima polishana',
#  'Elymnias hypermnestra',
#  'Neptis hylas luculenta',
#  'Ypthima multistriata',
#  'Eurema blanda arsakia',
#  'Somatochlora taiwana',
#  'Sarasaeschna lieni',
#  'Orthetrum internum',
#  'Ruidocollaris truncato-lobata',
#  'Dennstaedtia scandens',
#  'Neptis',
#  'Celosia',
#  'Aclees taiwanensis',
#  'Polydesmida',
#  'Lebeda nobilis',
#  'Sigmatoneura kolbei',
#  'Themus impressipennis',
#  'Antrophyum formosanum',
#  'Asplenium nidus',
#  'Tetrastigma obtectum glabrum',
#  'Urceola rosea',
#  'Hibiscus taiwanensis',
#  'Lampyridae',
#  'Hypolimnas bolina',
#  'Puhuaea sequax',
#  'Solanum torvum',
#  'Ampelopsis glandulosa',
#  'Brunia antica',
#  'Triumfetta pilosa',
#  'Boehmeria densiflora',
#  'Persicaria perfoliata',
#  'Pilea melastomoides',
#  'Epilachna',
#  'Achyranthes longifolia',
#  'Cassida japana',
#  'Ichneumonoidea',
#  'Geometrinae',
#  'Bacchini',
#  'Alternanthera sessilis',
#  'Spermacoce latifolia',
#  'Cuphea hyssopifolia',
#  'Cuscuta campestris',
#  'Oxalis corniculata',
#  'Centella asiatica',
#  'Pilea microphylla',
#  'Pleroma semidecandrum',
#  'Eclipta prostrata',
#  'Justicia procumbens',
#  'Magnolia figo',
#  'Lasianthus attenuatus attenuatus',
#  'Pandion haliaetus',
#  'Ficus',
#  'Cryptomeria japonica',
#  'Wendlandia formosana',
#  'Tenodera',
#  'Xenocatantops',
#  'Galinsoga quadriradiata',
#  'Alternanthera philoxeroides',
#  'Phyllanthus urinaria',
#  'Helicoidea',
#  'Rorippa dubia',
#  'Sigesbeckia orientalis',
#  'Ricaniidae',
#  'Agaricomycetes',
#  'Impatiens balsamina',
#  'Ficus formosana',
#  'Sarcopyramis napalensis',
#  'Torenia concolor',
#  'Scopula propinquaria',
#  'Lasianthus fordii',
#  'Aeschynanthus acuminatus',
#  'Ypthima esakii',
#  'Lasianthus curtisii',
#  'Scolopendra mutilans',
#  'Carex baccans',
#  'Piper sintenense',
#  'Coccinellinae',
#  'Epilachna sauteri',
#  'Bonnaya ruelloides',
#  'Blechnum orientale',
#  'Causonis corniculata',
#  'Nacaduba kurava therasia',
#  'Pomatorhinus musicus',
#  'Coelophora saucia',
#  'Aglaia odorata',
#  'Galerucinae',
#  'Stephania japonica',
#  'Ardea cinerea',
#  'Vanessa cardui',
#  'Polygala paniculata',
#  'Urena lobata',
#  'Spoladea recurvalis',
#  'Xanthosoma sagittifolium',
#  'Gallerucida singularis',
#  'Micropezidae',
#  'Neopanorpa youngi',
#  'Conocephalus melaenus',
#  'Glochidion acuminatum',
#  'Lema',
#  'Hemipyxis',
#  'Bactrocera',
#  'Isoteinon lamprospilus',
#  'Isodontia',
#  'Elatostema lineolatum',
#  'Ptecticus australis',
#  'Papilio protenor',
#  'Oxyini',
#  'Persicaria dichotoma',
#  'Emilia praetermissa',
#  'Copera marginipes',
#  'Gargela renatusalis',
#  'Portia labiata',
#  'Angiopteris lygodiifolia',
#  'Scopula',
#  'Plexippina',
#  'Callopistria',
#  'Cladonia',
#  'Emilia javanica',
#  'Cyanthillium cinereum',
#  'Elasmucha lineata',
#  'Blastus cochinchinensis',
#  'Geisha distinctissima',
#  'Perilla frutescens',
#  'Platostoma palustre',
#  'Menida lata',
#  'Solanum americanum',
#  'Callopistria japonibia',
#  'Apocrita',
#  'Choreutis basalis',
#  'Dacini',
#  'Mastira',
#  'Gallerucida',
#  'Chrysso scintillans',
#  'Musotima',
#  'Eysarcoris guttigerus',
#  'Coridius',
#  'Basidiomycota',
#  'Selaginella doederleinii',
#  'Polypodiidae',
#  'Deinagkistrodon acutus',
#  'Myrmeleontidae',
#  'Neuroptera',
#  'Asplenium pseudolaserpitiifolium',
#  'Asplenium ritoense',
#  'Crepidomanes minutum',
#  'Hymenophyllum badium',
#  'Hymenasplenium',
#  'Diplazium doederleinii',
#  'Argiope perforata',
#  'Mycalesis francisca formosana',
#  'Asota heliconia zebrina',
#  'Tectaria',
#  'Cibotium cumingii',
#  'Chlorodontopera discospilata',
#  'Thereuopoda clunifera',
#  'Symplocos',
#  'Diplopterygium blotianum',
#  'Chieniopteris harlandii',
#  'Nephrolepis biserrata',
#  'Ceriagrion nipponicum',
#  'Turpinia',
#  'Castanopsis carlesii',
#  'Pyracantha fortuneana',
#  'Tricyrtis formosana formosana',
#  'Brugmansia',
#  'Blumea megacephala',
#  'Aster indicus',
#  'Oplismenus compositus',
#  'Orthoptera',
#  'Tricyrtis formosana',
#  'Selaginella delicatula',
#  'Impatiens walleriana',
#  'Dumortiera hirsuta',
#  'Bryopsida',
#  'Celaenorrhinus oscula major',
#  'Halpe gamma',
#  'Farfugium japonicum formosanum',
#  'Eurema',
#  'Ochlodes bouddha',
#  'Dianthus barbatus',
#  'Phanera championii',
#  'Rubioideae',
#  'Oudemansiella mucida',
#  'Liliopsida',
#  'Cinclus pallasii',
#  'Chordata',
#  'Phoenicurus fuliginosus',
#  'Procris laevigata',
#  'Cerura',
#  'Trichosanthes cucumeroides',
#  'Impatiens',
#  'Geastraceae',
#  'Luffa aegyptiaca',
#  'Syzygium samarangense',
#  'Crematogaster rogenhoferi',
#  'Camellia',
#  'Favolus',
#  'Senna alata',
#  'Chamaecyparis formosensis',
#  'Diplazium laxifrons',
#  'Dryopteris sparsa',
#  'Impatiens uniflora',
#  'Reynoutria japonica',
#  'Gaultheria leucocarpa cumingiana',
#  'Polypodiopsida',
#  'Fagus hayatae',
#  'Atrichum',
#  'Pezizomycotina',
#  'Lepidozia',
#  'Selaginella remotifolia',
#  'Neolitsea acuminatissima',
#  'Ascomycota',
#  'Cunninghamia lanceolata',
#  'Rubus buergeri',
#  'Sarasaeschna tsaopiensis',
#  'Scutellerini',
#  'Cucurbita ficifolia',
#  'Ardisia elliptica',
#  'Psolodesmus mandarinus',
#  'Papilio paris nakaharai',
#  'Symbrenthia',
#  'Polyura eudamippus formosana',
#  'Anepsion roeweri',
#  'Dermatoxenus caesicollis',
#  'Heliophorus ila matsumurae',
#  'Oxyopes macilentus',
#  'Dolomedes',
#  'Epidaus',
#  'Sympetrum speciosum taiwanum',
#  'Megalestes riccii',
#  'Sinolestes editus',
#  'Siglophora ferreilutea',
#  'Abaciscus tristis',
#  'Biston perclara',
#  'Samia wangi',
#  'Notonagemia analis gressitti',
#  'Vamuna alboluteola',
#  'Tanaoctenia haliaria',
#  'Acosmeryx',
#  'Cechetra lineosa',
#  'Rhagastis castor formosana',
#  'Harpyia microsticta',
#  'Siglophora sanguinolenta',
#  'Oreta fuscopurpurea',
#  'Aceraius grandis',
#  'Balanophora laxiflora',
#  'Lanius cristatus',
#  'Phoenicurus auroreus',
#  'Emberiza spodocephala',
#  'Dendrocitta formosae',
#  'Centropus bengalensis',
#  'Lonchura striata',
#  'Propylea japonica',
#  'Diplacodes trivialis',
#  'Coelophora biplagiata',
#  'Acrididea',
#  'Strobilanthes formosana',
#  'Aegus',
#  'Paguma larvata taivana',
#  'Merus flavosignatus',
#  'Neocollyris',
#  'Polistes takasagonus',
#  'Tanaemyrmex',
#  'Heteropodinae',
#  'Barringtonia racemosa',
#  'Asplenium',
#  'Pseudopoda',
#  'Pleione formosana',
#  'Zingiber kawagoii',
#  'Callianthe',
#  'Puntius snyderi',
#  'Platycodon grandiflorus',
#  'Neurothemis taiwanensis',
#  'Formosania lacustris',
#  'Sapindus mukorossi',
#  'Paratimomenus flavocapitata',
#  'Bulbophyllum retusiusculum',
#  'Dendrocopos leucotos insularis',
#  'Boenninghausenia albiflora',
#  'Oxalis griffithii',
#  'Aster taiwanensis',
#  'Eupatorium formosanum',
#  'Ainsliaea macroclinidioides',
#  'Quercus sessilifolia',
#  'Ardisia crispa',
#  'Symplocos anomala',
#  'Pilea angulata',
#  'Rubus pectinellus',
#  'Adinandra lasiostyla',
#  'Clematis lasiandra',
#  'Rubus lambertianus',
#  'Tetrastigma hemsleyanum',
#  'Gardneria multiflora',
#  'Skimmia reevesiana',
#  'Camellia brevistyla',
#  'Cremastra appendiculata',
#  'Sabia transarisanensis',
#  'Eurya leptophylla',
#  'Lysimachia ardisioides',
#  'Trigonotis formosana elevatovenosa',
#  'Smilax elongatoumbellata',
#  'Idesia polycarpa',
#  'Lonicera apodantha',
#  'Photinia serratifolia',
#  'Rubus formosensis',
#  'Sageretia thea',
#  'Symplocos sumuntia',
#  'Lysionotus pauciflorus pauciflorus',
#  'Machilus thunbergii',
#  'Salvia nipponica formosana',
#  'Euonymus spraguei',
#  'Actinidia venosa',
#  'Ericales',
#  'Machilus japonica',
#  'Vaccinium emarginatum',
#  'Lindera communis',
#  'Sloanea dasycarpa',
#  'Endromidae',
#  'Capricornis swinhoei',
#  'Hydrophasianus chirurgus',
#  'Beilschmiedia erythrophloia',
#  'Ilex ficoidea',
#  'Disporopsis pernyi',
#  'Rhynchospermum verticillatum',
#  'Smilax lanceifolia',
#  'Tamiops maritimus',
#  'Viburnum foetidum rectangulatum',
#  'Zanthoxylum scandens',
#  'Arisaema formosanum',
#  'Hedera rhombea',
#  'Acrossocheilus paradoxus',
#  'Opsariichthys pachycephalus',
#  'Callopistria placodoides',
#  'Telicota ohara formosana',
#  'Parasa shirakii',
#  'Maesa japonica',
#  'Abies kawakamii',
#  'Sibatania arizana',
#  'Ardisia cornudentata morrisonensis',
#  'Heloniopsis umbellata',
#  'Codonacanthus pauciflorus',
#  'Periaeschna magdalena',
#  'Lecanoromycetes',
#  'Alpinia',
#  'Oudemansiella',
#  'Rubus rolfei',
#  'Rhododendron rubropilosum taiwanalpinum',
#  'Coprinellus disseminatus',
#  'Platyhelminthes',
#  'Russula',
#  'Carea varipes',
#  'Mazus fauriei',
#  'Rinaca thibeta okurai',
#  'Piper',
#  'Orgyia postica',
#  'Pterygida ornaticapitata',
#  'Poecilocoris lewisi',
#  'Syneilesis subglabrata',
#  'Calliandra haematocephala',
#  'Stereaceae',
#  'Callianthe picta',
#  'Indotyphlops braminus',
#  'Hebius sauteri',
#  'Pseudagkistrodon rudis',
#  'Oligodon ornatus',
#  'Sinomicrurus swinhoei',
#  'Elaphe carinata',
#  'Heptapleurum heptaphyllum',
#  'Pyrenaria microcarpa',
#  'Litsea acuminata',
#  'Lithocarpus',
#  'Cryptocarya chinensis',
#  'Symplocos glauca',
#  'Machilus zuihoensis mushaensis',
#  'Eurya crenatifolia',
#  'Lasianthus henryi',
#  'Symplocos cochinchinensis laurina',
#  'Ardisia chinensis',
#  'Helicia formosana',
#  'Abrodictyum obscurum',
#  'Hymenasplenium cheilosorum',
#  'Psilotum nudum',
#  'Pyrrosia lingua',
#  'Lasianthus micranthus',
#  'Liparis nakaharae',
#  'Ardisia quinquegona',
#  'Erycibe henryi',
#  'Dischidia formosana',
#  'Ilex pubescens',
#  'Vandenboschia auriculata',
#  'Araiostegia perdurans',
#  'Neolitsea konishii',
#  'Lithocarpus hancei',
#  'Prunus phaeosticta',
#  'Psychotria serpens',
#  'Meliosma squamulata',
#  'Pholidota cantonensis',
#  'Oreocnide pedunculata',
#  'Rhynchotechum discolor',
#  'Stegnogramma wilfordii',
#  'Hydrangea viburnoides',
#  'Haplopteris elongata',
#  'Lepidomicrosorium',
#  'Rubus pyrifolius',
#  'Haplopteris flexuosa',
#  'Machilus japonica kusanoi',
#  'Cephalantheropsis obcordata',
#  'Eurya loquaiana',
#  'Castanopsis cuspidata carlesii',
#  'Calamus formosanus',
#  'Elaphoglossum yoshinagae',
#  'Engelhardia roxburghiana',
#  'Melastoma malabathricum',
#  'Phoebe formosana',
#  'Zanthoxylum ailanthoides',
#  'Callicarpa kochiana',
#  'Macrobrachium asperulum',
#  'Pergesa acteus',
#  'Cinclus pallasii pallasii',
#  'Rhodeus ocellatus',
#  'Bambusicola sonorivox',
#  'Nannophya pygmaea',
#  'Cymatoderma elegans',
#  'Rhomboda yakusimensis',
#  'Diplazium donianum',
#  'Tainia cordifolia',
#  'Asplenium normale',
#  'Polyspora axillaris',
#  'Magnolia compressa formosana',
#  'Ardisia sieboldii',
#  'Gynostemma pentaphyllum',
#  'Ardisia brevicaulis',
#  ...]

# %%
# MAKE SPECIES 01 LIST
'''
list_XXX=[]
for i in range(len(species_all)):
    if(species_all[i] in species_XXX):
        #print(species_all[i])
        list_XXX.append(1)
    else:
        list_XXX.append(0)
'''

list_CuKeng=[]
for i in range(len(species_all)):
    if(species_all[i] in species_CuKeng):
        #print(species_all[i])
        list_CuKeng.append(1)
    else:
        list_CuKeng.append(0)

list_NanShi=[]
for i in range(len(species_all)):
    if(species_all[i] in species_NanShi):
        #print(species_all[i])
        list_NanShi.append(1)
    else:
        list_NanShi.append(0)

list_SongLuo=[]
for i in range(len(species_all)):
    if(species_all[i] in species_SongLuo):
        #print(species_all[i])
        list_SongLuo.append(1)
    else:
        list_SongLuo.append(0)
        
list_FanFan=[]
for i in range(len(species_all)):
    if(species_all[i] in species_FanFan):
        #print(species_all[i])
        list_FanFan.append(1)
    else:
        list_FanFan.append(0)


list_SanGuang=[]
for i in range(len(species_all)):
    if(species_all[i] in species_SanGuang):
        #print(species_all[i])
        list_SanGuang.append(1)
    else:
        list_SanGuang.append(0)
        
list_BaoYan=[]
for i in range(len(species_all)):
    if(species_all[i] in species_BaoYan):
        #print(species_all[i])
        list_BaoYan.append(1)
    else:
        list_BaoYan.append(0)
        
list_FuBuEr=[]
for i in range(len(species_all)):
    if(species_all[i] in species_FuBuEr):
        #print(species_all[i])
        list_FuBuEr.append(1)
    else:
        list_FuBuEr.append(0)
        
list_MeiYou=[]
for i in range(len(species_all)):
    if(species_all[i] in species_MeiYou):
        #print(species_all[i])
        list_MeiYou.append(1)
    else:
        list_MeiYou.append(0)

list_QingShui=[]
for i in range(len(species_all)):
    if(species_all[i] in species_QingShui):
        #print(species_all[i])
        list_QingShui.append(1)
    else:
        list_QingShui.append(0)
        
list_TianGou=[]
for i in range(len(species_all)):
    if(species_all[i] in species_TianGou):
        #print(species_all[i])
        list_TianGou.append(1)
    else:
        list_TianGou.append(0)
        
list_TuChang=[]
for i in range(len(species_all)):
    if(species_all[i] in species_TuChang):
        #print(species_all[i])
        list_TuChang.append(1)
    else:
        list_TuChang.append(0)
        
list_MeiLuo=[]
for i in range(len(species_all)):
    if(species_all[i] in species_MeiLuo):
        #print(species_all[i])
        list_MeiLuo.append(1)
    else:
        list_MeiLuo.append(0)
        
list_TaiGang=[]
for i in range(len(species_all)):
    if(species_all[i] in species_TaiGang):
        #print(species_all[i])
        list_TaiGang.append(1)
    else:
        list_TaiGang.append(0)

# %%
# SAVE TO CSV

dict = {'all': species_all, 'BaoYan': list_BaoYan, 'CuKeng': list_CuKeng, 'FanFan': list_FanFan, 
        'FuBuEr': list_FuBuEr, 'MeiLuo': list_MeiLuo, 'MeiYou': list_MeiYou,
       'NanShi': list_NanShi, 'QingShui': list_QingShui, 'SongLuo': list_SongLuo,
       'SanGuang': list_SanGuang, 'TianGou': list_TianGou, 'TuChang': list_TuChang,
       'TaiGang': list_TaiGang}
     
df = pd.DataFrame(dict)
df = df.T

df.to_csv('result.csv', header=False)
print("result.csv SAVE!")
# Out:
# result.csv SAVE!

# %%
# STATISTICAL DATA 
'''
list_class_XXX = [0]*len(class_all)
for i in range(len(df_XXX)):
    for j in range(len(class_all)):
        if(df_XXX['taxon_clas'][i] in class_all[j]):
            list_class_XXX[j] += 1;
'''
class_all = df_all['taxon_clas'].drop_duplicates().reset_index(drop=True).tolist()

list_class_CuKeng = [0]*len(class_all)
for i in range(len(df_CuKeng)):
    for j in range(len(class_all)):
        if(df_CuKeng['taxon_clas'][i] in class_all[j]):
            list_class_CuKeng[j] += 1;
            
list_class_NanShi = [0]*len(class_all)
for i in range(len(df_NanShi)):
    for j in range(len(class_all)):
        if(df_NanShi['taxon_clas'][i] in class_all[j]):
            list_class_NanShi[j] += 1;
            
list_class_SongLuo = [0]*len(class_all)
for i in range(len(df_SongLuo)):
    for j in range(len(class_all)):
        if(df_SongLuo['taxon_clas'][i] in class_all[j]):
            list_class_SongLuo[j] += 1;
            
list_class_FanFan = [0]*len(class_all)
for i in range(len(df_FanFan)):
    for j in range(len(class_all)):
        if(df_FanFan['taxon_clas'][i] in class_all[j]):
            list_class_FanFan[j] += 1;            

list_class_SanGuang = [0]*len(class_all)
for i in range(len(df_SanGuang)):
    for j in range(len(class_all)):
        if(df_SanGuang['taxon_clas'][i] in class_all[j]):
            list_class_SanGuang[j] += 1;
            
list_class_BaoYan = [0]*len(class_all)
for i in range(len(df_BaoYan)):
    for j in range(len(class_all)):
        if(df_BaoYan['taxon_clas'][i] in class_all[j]):
            list_class_BaoYan[j] += 1;
            
list_class_FuBuEr = [0]*len(class_all)
for i in range(len(df_FuBuEr)):
    for j in range(len(class_all)):
        if(df_FuBuEr['taxon_clas'][i] in class_all[j]):
            list_class_FuBuEr[j] += 1;           
            
list_class_MeiYou = [0]*len(class_all)
for i in range(len(df_MeiYou)):
    for j in range(len(class_all)):
        if(df_MeiYou['taxon_clas'][i] in class_all[j]):
            list_class_MeiYou[j] += 1;
            
list_class_QingShui = [0]*len(class_all)
for i in range(len(df_QingShui)):
    for j in range(len(class_all)):
        if(df_QingShui['taxon_clas'][i] in class_all[j]):
            list_class_QingShui[j] += 1;
            
list_class_TianGou = [0]*len(class_all)
for i in range(len(df_TianGou)):
    for j in range(len(class_all)):
        if(df_TianGou['taxon_clas'][i] in class_all[j]):
            list_class_TianGou[j] += 1;             
            
list_class_TuChang = [0]*len(class_all)
for i in range(len(df_TuChang)):
    for j in range(len(class_all)):
        if(df_TuChang['taxon_clas'][i] in class_all[j]):
            list_class_TuChang[j] += 1;
            
list_class_MeiLuo = [0]*len(class_all)
for i in range(len(df_MeiLuo)):
    for j in range(len(class_all)):
        if(df_MeiLuo['taxon_clas'][i] in class_all[j]):
            list_class_MeiLuo[j] += 1;   


list_class_TaiGang = [0]*len(class_all)
for i in range(len(df_TaiGang)):
    for j in range(len(class_all)):
        if(df_TaiGang['taxon_clas'][i] in class_all[j]):
            list_class_TaiGang[j] += 1;
            

dict = {'all': class_all, 'BaoYan': list_class_BaoYan, 'CuKeng': list_class_CuKeng, 'FanFan': list_class_FanFan, 
        'FuBuEr': list_class_FuBuEr, 'MeiLuo': list_class_MeiLuo, 'MeiYou': list_class_MeiYou,
       'NanShi': list_class_NanShi, 'QingShui': list_class_QingShui, 'SongLuo': list_class_SongLuo,
       'SanGuang': list_class_SanGuang, 'TianGou': list_class_TianGou, 'TuChang': list_class_TuChang,
       'TaiGang': list_class_TaiGang}
     
df = pd.DataFrame(dict)
df = df.T

df.to_csv('StatisticalData.csv', header=False)
print("StatisticalData.csv SAVE!")
# Out:
# StatisticalData.csv SAVE!
