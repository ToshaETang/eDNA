# %%
import pandas as pd

# %%
df_all=pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\工作\eDNA\sub_river_creatures\1010\all.csv')

df_BaoYan=pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\工作\eDNA\sub_river_creatures\1010\BaoYan.csv')
df_CuKeng=pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\工作\eDNA\sub_river_creatures\1010\CuKeng.csv')
df_FanFan=pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\工作\eDNA\sub_river_creatures\1010\FanFan.csv')
df_FuBuEr=pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\工作\eDNA\sub_river_creatures\1010\FuBuEr.csv')
df_MeiLuo=pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\工作\eDNA\sub_river_creatures\1010\MeiLuo.csv')
df_MeiYou=pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\工作\eDNA\sub_river_creatures\1010\MeiYou.csv')
df_NanShi=pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\工作\eDNA\sub_river_creatures\1010\NanShi.csv')
df_QingShui=pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\工作\eDNA\sub_river_creatures\1010\QingShui.csv')
df_SongLuo=pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\工作\eDNA\sub_river_creatures\1010\SongLuo.csv')
df_SanGuang=pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\工作\eDNA\sub_river_creatures\1010\SanGuang.csv')
df_TianGou=pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\工作\eDNA\sub_river_creatures\1010\TianGou.csv')
df_TuChang=pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\工作\eDNA\sub_river_creatures\1010\TuChang.csv')

df_all=df_all.values.tolist()
df_BaoYan=df_BaoYan.values.tolist()
df_CuKeng=df_CuKeng.values.tolist()
df_FanFan=df_FanFan.values.tolist()
df_FuBuEr=df_FuBuEr.values.tolist()
df_MeiLuo=df_MeiLuo.values.tolist()
df_MeiYou=df_MeiYou.values.tolist()
df_NanShi=df_NanShi.values.tolist()
df_QingShui=df_QingShui.values.tolist()
df_SongLuo=df_SongLuo.values.tolist()
df_SanGuang=df_SanGuang.values.tolist()
df_TianGou=df_TianGou.values.tolist()
df_TuChang=df_TuChang.values.tolist()

# %%
print(len(df_all))
# Out:
# 6431

# %%
list_BaoYan=[]
for i in range(len(df_all)):
    if(df_all[i] in df_BaoYan):
        #print(df_all[i])
        list_BaoYan.append(1)
    else:
        list_BaoYan.append(0)

list_CuKeng=[]
for i in range(len(df_all)):
    if(df_all[i] in df_CuKeng):
        #print(df_all[i])
        list_CuKeng.append(1)
    else:
        list_CuKeng.append(0)
        
list_FanFan=[]
for i in range(len(df_all)):
    if(df_all[i] in df_FanFan):
        #print(df_all[i])
        list_FanFan.append(1)
    else:
        list_FanFan.append(0)

list_FuBuEr=[]
for i in range(len(df_all)):
    if(df_all[i] in df_FuBuEr):
        #print(df_all[i])
        list_FuBuEr.append(1)
    else:
        list_FuBuEr.append(0)
        
list_MeiLuo=[]
for i in range(len(df_all)):
    if(df_all[i] in df_MeiLuo):
        #print(df_all[i])
        list_MeiLuo.append(1)
    else:
        list_MeiLuo.append(0)
        
list_MeiYou=[]
for i in range(len(df_all)):
    if(df_all[i] in df_MeiYou):
        #print(df_all[i])
        list_MeiYou.append(1)
    else:
        list_MeiYou.append(0)
        
list_NanShi=[]
for i in range(len(df_all)):
    if(df_all[i] in df_NanShi):
        #print(df_all[i])
        list_NanShi.append(1)
    else:
        list_NanShi.append(0)
        
list_QingShui=[]
for i in range(len(df_all)):
    if(df_all[i] in df_QingShui):
        #print(df_all[i])
        list_QingShui.append(1)
    else:
        list_QingShui.append(0)
        
list_SongLuo=[]
for i in range(len(df_all)):
    if(df_all[i] in df_SongLuo):
        #print(df_all[i])
        list_SongLuo.append(1)
    else:
        list_SongLuo.append(0)
        
list_SanGuang=[]
for i in range(len(df_all)):
    if(df_all[i] in df_SanGuang):
        #print(df_all[i])
        list_SanGuang.append(1)
    else:
        list_SanGuang.append(0)
        
list_TianGou=[]
for i in range(len(df_all)):
    if(df_all[i] in df_TianGou):
        #print(df_all[i])
        list_TianGou.append(1)
    else:
        list_TianGou.append(0)
        
list_TuChang=[]
for i in range(len(df_all)):
    if(df_all[i] in df_TuChang):
        #print(df_all[i])
        list_TuChang.append(1)
    else:
        list_TuChang.append(0)

# %%
#print(len(df_all))

#print(list_BaoYan)
#print(len(list_BaoYan))

# %%
# dictionary of lists
dict = {'all': df_all, 'BaoYan': list_BaoYan, 'CuKeng': list_CuKeng, 'FanFan': list_FanFan, 
        'FuBuEr': list_FuBuEr, 'MeiLuo': list_MeiLuo, 'MeiYou': list_MeiYou,
       'NanShi': list_NanShi, 'QingShui': list_QingShui, 'SongLuo': list_SongLuo,
       'SanGuang': list_SanGuang, 'TianGou': list_TianGou, 'TuChang': list_TuChang}
     
df = pd.DataFrame(dict)
     
# saving the dataframe
df.to_csv('result.csv')
